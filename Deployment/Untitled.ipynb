# %%
import numpy as np
import pandas as pd

# %%
iris = pd.read_csv("./Data/iris.csv")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
X = iris.drop('species', axis=1)
y = iris['species']

# %%
y.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
from sklearn.preprocessing import LabelBinarizer

# %%
encoder = LabelBinarizer()

# %%
y = encoder.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
# scaled_X_train = scaler.transform(X_train)
scaled_X_test = scaler.transform(X_test)

# %% [markdown]
# # MODEL

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(units=4, activation='relu', input_shape=[4,]))
model.add(Dense(units=3, activation='softmax'))

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 4)                 20
#
#  dense_5 (Dense)             (None, 3)                 15
#
# ...
# Total params: 35
# Trainable params: 35
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(patience=10)

# %%
model.fit(x=scaled_X_train, y=y_train, epochs=300,
          validation_data=(scaled_X_test, y_test), callbacks=[early_stop])
# Out:
# Epoch 1/300
# 4/4 [==============================] - 2s 146ms/step - loss: 1.1704 - accuracy: 0.3333 - val_loss: 1.1102 - val_accuracy: 0.3333
# Epoch 2/300
# 4/4 [==============================] - 0s 18ms/step - loss: 1.1605 - accuracy: 0.3333 - val_loss: 1.1035 - val_accuracy: 0.3333
# Epoch 3/300
# 4/4 [==============================] - 0s 18ms/step - loss: 1.1510 - accuracy: 0.3333 - val_loss: 1.0968 - val_accuracy: 0.3333
# Epoch 4/300
# 4/4 [==============================] - 0s 18ms/step - loss: 1.1417 - accuracy: 0.3333 - val_loss: 1.0904 - val_accuracy: 0.3333
# Epoch 5/300
# 4/4 [==============================] - 0s 18ms/step - loss: 1.1323 - accuracy: 0.3333 - val_loss: 1.0839 - val_accuracy: 0.3333
# Epoch 6/300
# 4/4 [==============================] - 0s 18ms/step - loss: 1.1226 - accuracy: 0.3333 - val_loss: 1.0775 - val_accuracy: 0.3333
# Epoch 7/300
# ...

# %%
metrics = pd.DataFrame(model.history.history)

# %%
metrics.columns
# Out:
# Index(['loss', 'accuracy', 'val_loss', 'val_accuracy'], dtype='object')

# %%
metrics[['loss', 'accuracy', 'val_loss', 'val_accuracy']].plot()
# Out:
# <AxesSubplot:>

# %%
model.evaluate(scaled_X_test, y_test, verbose=0)
# Out:
# [0.3628711700439453, 0.9666666388511658]

# %%
epochs = len(metrics)

# %%
epochs
# Out:
# 300

# %%
scaled_X = scaler.fit_transform(X)

# %%
model = Sequential()
model.add(Dense(units=4, activation='relu', input_shape=[4,]))
model.add(Dense(units=3, activation='softmax'))

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(scaled_X, y, epochs=epochs)
# Out:
# Epoch 1/300
# 5/5 [==============================] - 1s 4ms/step - loss: 1.0128 - accuracy: 0.2733
# Epoch 2/300
# 5/5 [==============================] - 0s 5ms/step - loss: 1.0071 - accuracy: 0.3000
# Epoch 3/300
# 5/5 [==============================] - 0s 3ms/step - loss: 1.0025 - accuracy: 0.3000
# Epoch 4/300
# 5/5 [==============================] - 0s 6ms/step - loss: 0.9972 - accuracy: 0.2733
# Epoch 5/300
# 5/5 [==============================] - 0s 5ms/step - loss: 0.9918 - accuracy: 0.2933
# Epoch 6/300
# 5/5 [==============================] - 0s 6ms/step - loss: 0.9861 - accuracy: 0.3267
# Epoch 7/300
# 5/5 [==============================] - 0s 6ms/step - loss: 0.9804 - accuracy: 0.3467
# Epoch 8/300
# 5/5 [==============================] - 0s 4ms/step - loss: 0.9744 - accuracy: 0.3533
# Epoch 9/300
# 5/5 [==============================] - 0s 6ms/step - loss: 0.9682 - accuracy: 0.3667
# Epoch 10/300
# ...

# %%
model.save("final_iris_model.h5")

# %%
import joblib

# %%
joblib.dump(scaler,'iris_scaler.pkl')
# Out:
# ['iris_scaler.pkl']

# %%
from tensorflow.keras.models import load_model

# %%
flower_model = load_model('final_iris_model.h5')
flower_sacler = joblib.load("iris_scaler.pkl")

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
iris.head(1)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa

# %%
encoder.classes_
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
flower_example = {'sepal_length': 5.1,
                  'sepal_width': 3.5,
                  'petal_length': 1.4,
                  'petal_width': 0.2}

# %%
def return_prediction(model, scaler, sample_json):
    s_len = sample_json['sepal_length']
    s_wid = sample_json['sepal_width']
    p_len = sample_json['petal_length']
    p_wid = sample_json['petal_width']
    
    flower = [[s_len, s_wid, p_len, p_wid]]
    
    classes = np.array(['setosa', 'versicolor', 'virginica'])
    
    flower = scaler.transform(flower)
    
    #(model.predict(x) > 0.5).astype("int32")---when using sigmoid
    class_ind = np.argmax(model.predict(flower), axis=1)[0]
    
    return classes[class_ind]

# %%
return_prediction(flower_model, flower_sacler, flower_example)
# Out:
# 1/1 [==============================] - 0s 37ms/step
# C:\Users\Charles\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 'setosa'

# %% [markdown]
# # CODE FOR DEPLOYMENT

# %%
from tensorflow.keras.models import load_model
import numpy as np
from joblib import load

flower_model = load_model('final_iris_model.h5')
flower_sacler = joblib.load("iris_scaler.pkl")

def return_prediction(model, scaler, sample_json):
    s_len = sample_json['sepal_length']
    s_wid = sample_json['sepal_width']
    p_len = sample_json['petal_length']
    p_wid = sample_json['petal_width']
    
    flower = [[s_len, s_wid, p_len, p_wid]]
    
    classes = np.array(['setosa', 'versicolor', 'virginica'])
    
    flower = scaler.transform(flower)
    
    #(model.predict(x) > 0.5).astype("int32")---when using sigmoid
    class_ind = np.argmax(model.predict(flower), axis=1)[0]
    
    return classes[class_ind]
